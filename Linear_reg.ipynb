# %% [markdown]
# # Modelos Lineares

# %% [markdown]
# #### Nicolas Soares e Klayver Paz

# %% [markdown]
#  1. Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
plt.style.use('seaborn')
sns.set(style='darkgrid')

# %% [markdown]
# ## Regressão Linear Simples

# %%
df = pd.DataFrame({'Peso': np.array([18.141,42.404,16.1,13.005,23.583,7.710,17.46,3.855,14.966,4.308,9.524,35.828]),
                    'Altura': np.array([1.087,1.613,0.953,1.003,1.156,0.978,1.092,0.572,0.940,0.597,0.838,1.473]),
                    'Cateter': np.array([37, 50, 34, 36, 43, 28, 37, 20, 34, 30, 38, 47])})
x1 = np.array(df[["Altura"]])
y1 = np.array(df[["Cateter"]])
df
# Out:
#       Peso  Altura  Cateter
# 0   18.141   1.087       37
# 1   42.404   1.613       50
# 2   16.100   0.953       34
# 3   13.005   1.003       36
# 4   23.583   1.156       43
# 5    7.710   0.978       28
# 6   17.460   1.092       37
# 7    3.855   0.572       20
# 8   14.966   0.940       34
# 9    4.308   0.597       30
# 10   9.524   0.838       38
# 11  35.828   1.473       47

# %% [markdown]
# #### REGRESSÃO LINEAR SIMPLES - ANALÍTICA

# %%
#Regressão Linear Simples
# yi=w0+w1xi equação da reta

# %%
#trabalhando somente com uma dimensao
X=df[['Altura']]
y=df['Cateter']
plt.plot(X,y,'o', color='black')
plt.title('Dados\n', fontsize=20)
plt.xlabel('Altura do paciente (m)')
plt.ylabel('Tamanho do Cateter (cm)')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(X,y)
y_pred=lm.predict(X)

from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y)
# Out:
# 12.453723207543378

# %%
#QUERO PLOTAR O PARABOLOIDE DO ERRO 
from mpl_toolkits.mplot3d import Axes3D
x1=np.arange(-100,100,0.5)
y1=x1
#criando coordenadas em 3D
X,Y = np.meshgrid(x1, y1)
#Função a ser plotada U(x,y)
#somatorio=0
#fc=[]
#for i in range(len(x)):
#    e= y.loc[i] - y_predict[i]
#    somatorio = somatorio + (e)**2
#    fc.append(somatorio/(2*len(x)))
U = X**2+Y**2
#Vinculando a figura as coordenadas 3D
fig = plt.figure()
ax = Axes3D(fig)
#plotando grafico 
ax.plot_surface(X,Y,U)
plt.show()

# %% [markdown]
# #### REGRESSÃO LINEAR SIMPLES - SCIKITLEARN IMPLEMENTATION

# %%
def graf():
    # plt.show()
    print(f"EQUATION: Theta(x) = {a}x + {b} , R² = {R2}")

X = np.array(df[["Altura"]])
y = np.array(df[["Cateter"]])
reg = linear_model.LinearRegression()
reg.fit(X, y)
R2 = reg.score(X, y)
a = reg.coef_
b = reg.intercept_
y_pred = reg.predict(X)


#ploting Graph
plt.scatter(X, y, color='black', marker ="x", s = 100)
plt.plot(X,y_pred, color='blue', linewidth=3, label ="Linha de predição")
plt.legend()
plt.title("Linear Regression")
plt.xlabel("Peso")
plt.ylabel("Altura")
plt.grid()
plt.show()b

graf()


from sklearn.metrics import mean_squared_error
print('RMS: ',mean_squared_error(y_pred,y))
# Out:
# EQUATION: Theta(x) = [[24.08702511]]x + [11.47345142] , R² = 0.7968581624505837
# RMS:  12.453723207543378

# %% [markdown]
# ### Regressão Linear Multipla - Scikit

# %%
u = df[["Peso", "Altura"]]
v = df[["Cateter"]]

reg = linear_model.LinearRegression()
reg.fit(u, v)
R2 = reg.score(u, v)
a = reg.coef_
b = reg.intercept_
print(a,b)

# %% [markdown]
# # Implementações

# %% [markdown]
# ##### GRADIENTE DESCENDENTE

# %%
def gradiente_descendente(x, y, Custo = None):
    wo = w = 0
    inter = 1000
    alpha = 0.08 #learning rate
    n = len(x)
    custo = custot = np.array([])

    for t in range(inter):
        y_pred = x*w + wo
        custot = ((1/n) * sum([val**2 for val in (y-y_pred)]))
        custo = np.append(custo, custot) 
        derivada_w  = -(2/n)  *  sum(x*(y-y_pred))
        derivada_wo = -(2/n)  *  sum(y-y_pred)
        w =  w  - alpha*derivada_w
        wo = wo - alpha*derivada_wo
        print(f"Theta(x) = {w}x + {wo}, custo ({custot}),  [{t}]")
    
    plt.scatter(x, y, marker = "x", color = "black")
    plt.plot(x,y_pred, color = "red")
    plt.xlabel("Independent variable")
    plt.ylabel("Dependent Variable")
    plt.show()
    print(f"Theta(x) = {w[-1]}x + {wo[-1]}")
    if Custo:
      plt.plot(np.array([t for t in range(0, inter)]), custo, color = "orange")
      plt.xlabel("Iteration")
      plt.ylabel("Cost function")
      plt.show()
   

gradiente_descendente(x1, y1, Custo = True)
# Out:
# Theta(x) = [6.2568]x + [5.78666667], custo ([1369.33333333]),  [0]
# Theta(x) = [10.42803013]x + [9.62118462], custo ([613.57903817]),  [1]
# Theta(x) = [13.2126901]x + [12.15798672], custo ([279.54429143]),  [2]
# Theta(x) = [15.07547815]x + [13.832142], custo ([131.89474129]),  [3]
# Theta(x) = [16.32532795]x + [14.93288552], custo ([66.62101603]),  [4]
# Theta(x) = [17.16762031]x + [15.65250138], custo ([37.75468941]),  [5]
# Theta(x) = [17.73889366]x + [16.11882029], custo ([24.97935775]),  [6]
# Theta(x) = [18.12991975]x + [16.41682411], custo ([19.31589417]),  [7]
# Theta(x) = [18.40104447]x + [16.60300862], custo ([16.79584281]),  [8]
# Theta(x) = [18.59238647]x + [16.71493192], custo ([15.66528522]),  [9]
# Theta(x) = [18.73061724]x + [16.7775623], custo ([15.14904938]),  [10]
# Theta(x) = [18.83346855]x + [16.80749829], custo ([14.90453421]),  [11]
# Theta(x) = [18.91272901]x + [16.81577416], custo ([14.78031956]),  [12]
# Theta(x) = [18.97623618]x + [16.80972506], custo ([14.70948045]),  [13]
# Theta(x) = [19.02920097]x + [16.79422695], custo ([14.66243578]),  [14]
# Theta(x) = [19.07508804]x + [16.7725209], custo ([14.62610915]),  [15]
# Theta(x) = [19.11620116]x + [16.74676112], custo ([14.59471865]),  [16]
# Theta(x) = [19.15407233]x + [16.71837925], custo ([14.56570635]),  [17]
# Theta(x) = [19.18972047]x + [16.6883266], custo ([14.5379392]),  [18]
# Theta(x) = [19.22382339]x + [16.65723513], custo ([14.51091397]),  [19]
# Theta(x) = [19.25683213]x + [16.6255245], custo ([14.48440576]),  [20]
# Theta(x) = [19.289047]x + [16.59347326], custo ([14.45831277]),  [21]
# Theta(x) = [19.32066804]x + [16.56126613], custo ([14.43258761]),  [22]
# Theta(x) = [19.35182868]x + [16.52902544], custo ([14.40720697]),  [23]
# Theta(x) = [19.38261805]x + [16.49683208], custo ([14.38215822]),  [24]
# Theta(x) = [19.41309581]x + [16.46473938], custo ([14.35743347]),  [25]
# Theta(x) = [19.44330206]x + [16.43278235], custo ([14.33302696]),  [26]
# Theta(x) = [19.47326385]x + [16.40098382], custo ([14.30893391]),  [27]
# Theta(x) = [19.50299958]x + [16.36935852], custo ([14.28514997]),  [28]
# Theta(x) = [19.53252191]x + [16.33791581], custo ([14.26167105]),  [29]
# Theta(x) = [19.56183963]x + [16.30666149], custo ([14.23849318]),  [30]
# Theta(x) = [19.59095901]x + [16.27559897], custo ([14.21561248]),  [31]
# Theta(x) = [19.61988461]x + [16.2447301], custo ([14.19302511]),  [32]
# Theta(x) = [19.64861987]x + [16.21405567], custo ([14.17072731]),  [33]
# Theta(x) = [19.67716746]x + [16.18357581], custo ([14.14871537]),  [34]
# Theta(x) = [19.70552956]x + [16.15329016], custo ([14.12698563]),  [35]
# Theta(x) = [19.73370799]x + [16.12319807], custo ([14.10553446]),  [36]
# Theta(x) = [19.76170437]x + [16.0932987], custo ([14.08435829]),  [37]
# Theta(x) = [19.78952016]x + [16.06359108], custo ([14.06345361]),  [38]
# Theta(x) = [19.81715669]x + [16.03407415], custo ([14.04281692]),  [39]
# Theta(x) = [19.84461526]x + [16.0047468], custo ([14.02244479]),  [40]
# Theta(x) = [19.87189708]x + [15.97560788], custo ([14.00233383]),  [41]
# Theta(x) = [19.89900336]x + [15.94665625], custo ([13.98248069]),  [42]
# Theta(x) = [19.92593525]x + [15.91789073], custo ([13.96288207]),  [43]
# Theta(x) = [19.9526939]x + [15.88931014], custo ([13.94353471]),  [44]
# Theta(x) = [19.97928044]x + [15.86091331], custo ([13.92443537]),  [45]
# Theta(x) = [20.00569599]x + [15.83269907], custo ([13.90558089]),  [46]
# Theta(x) = [20.03194166]x + [15.80466626], custo ([13.88696812]),  [47]
# Theta(x) = [20.05801854]x + [15.77681371], custo ([13.86859397]),  [48]
# Theta(x) = [20.08392773]x + [15.74914026], custo ([13.85045538]),  [49]
# Theta(x) = [20.10967029]x + [15.72164477], custo ([13.83254932]),  [50]
# Theta(x) = [20.13524732]x + [15.69432608], custo ([13.81487281]),  [51]
# Theta(x) = [20.16065986]x + [15.66718308], custo ([13.79742292]),  [52]
# Theta(x) = [20.18590898]x + [15.64021462], custo ([13.78019673]),  [53]
# Theta(x) = [20.21099574]x + [15.61341958], custo ([13.76319139]),  [54]
# Theta(x) = [20.23592116]x + [15.58679685], custo ([13.74640405]),  [55]
# Theta(x) = [20.26068631]x + [15.56034533], custo ([13.72983192]),  [56]
# Theta(x) = [20.28529219]x + [15.5340639], custo ([13.71347225]),  [57]
# Theta(x) = [20.30973984]x + [15.50795149], custo ([13.69732231]),  [58]
# Theta(x) = [20.33403028]x + [15.48200699], custo ([13.68137941]),  [59]
# Theta(x) = [20.35816451]x + [15.45622933], custo ([13.6656409]),  [60]
# Theta(x) = [20.38214355]x + [15.43061744], custo ([13.65010416]),  [61]
# Theta(x) = [20.40596838]x + [15.40517025], custo ([13.63476659]),  [62]
# Theta(x) = [20.42964001]x + [15.3798867], custo ([13.61962565]),  [63]
# Theta(x) = [20.45315941]x + [15.35476574], custo ([13.60467882]),  [64]
# Theta(x) = [20.47652756]x + [15.32980633], custo ([13.58992361]),  [65]
# Theta(x) = [20.49974545]x + [15.30500742], custo ([13.57535756]),  [66]
# Theta(x) = [20.52281402]x + [15.28036799], custo ([13.56097824]),  [67]
# Theta(x) = [20.54573425]x + [15.255887], custo ([13.54678327]),  [68]
# Theta(x) = [20.56850709]x + [15.23156345], custo ([13.53277028]),  [69]
# Theta(x) = [20.59113348]x + [15.20739631], custo ([13.51893693]),  [70]
# Theta(x) = [20.61361437]x + [15.18338458], custo ([13.50528093]),  [71]
# Theta(x) = [20.6359507]x + [15.15952726], custo ([13.49179999]),  [72]
# Theta(x) = [20.65814338]x + [15.13582336], custo ([13.47849188]),  [73]
# Theta(x) = [20.68019336]x + [15.11227189], custo ([13.46535438]),  [74]
# Theta(x) = [20.70210153]x + [15.08887187], custo ([13.4523853]),  [75]
# Theta(x) = [20.72386883]x + [15.06562233], custo ([13.43958249]),  [76]
# Theta(x) = [20.74549614]x + [15.0425223], custo ([13.4269438]),  [77]
# Theta(x) = [20.76698438]x + [15.01957082], custo ([13.41446715]),  [78]
# Theta(x) = [20.78833443]x + [14.99676693], custo ([13.40215044]),  [79]
# Theta(x) = [20.80954719]x + [14.97410968], custo ([13.38999164]),  [80]
# Theta(x) = [20.83062354]x + [14.95159814], custo ([13.37798871]),  [81]
# Theta(x) = [20.85156435]x + [14.92923136], custo ([13.36613965]),  [82]
# Theta(x) = [20.8723705]x + [14.90700842], custo ([13.35444251]),  [83]
# Theta(x) = [20.89304285]x + [14.88492838], custo ([13.34289531]),  [84]
# Theta(x) = [20.91358226]x + [14.86299033], custo ([13.33149616]),  [85]
# Theta(x) = [20.93398959]x + [14.84119336], custo ([13.32024314]),  [86]
# Theta(x) = [20.95426569]x + [14.81953655], custo ([13.30913438]),  [87]
# Theta(x) = [20.9744114]x + [14.79801902], custo ([13.29816804]),  [88]
# Theta(x) = [20.99442756]x + [14.77663985], custo ([13.28734228]),  [89]
# Theta(x) = [21.01431501]x + [14.75539817], custo ([13.27665532]),  [90]
# Theta(x) = [21.03407456]x + [14.73429309], custo ([13.26610535]),  [91]
# Theta(x) = [21.05370705]x + [14.71332372], custo ([13.25569064]),  [92]
# Theta(x) = [21.07321329]x + [14.69248921], custo ([13.24540944]),  [93]
# Theta(x) = [21.09259409]x + [14.67178867], custo ([13.23526005]),  [94]
# Theta(x) = [21.11185025]x + [14.65122125], custo ([13.22524078]),  [95]
# Theta(x) = [21.13098259]x + [14.63078609], custo ([13.21534995]),  [96]
# Theta(x) = [21.1499919]x + [14.61048235], custo ([13.20558592]),  [97]
# Theta(x) = [21.16887896]x + [14.59030917], custo ([13.19594706]),  [98]
# Theta(x) = [21.18764457]x + [14.57026571], custo ([13.18643178]),  [99]
# Theta(x) = [21.2062895]x + [14.55035115], custo ([13.17703848]),  [100]
# Theta(x) = [21.22481453]x + [14.53056466], custo ([13.1677656]),  [101]
# Theta(x) = [21.24322043]x + [14.5109054], custo ([13.1586116]),  [102]
# Theta(x) = [21.26150797]x + [14.49137257], custo ([13.14957496]),  [103]
# Theta(x) = [21.27967791]x + [14.47196534], custo ([13.14065416]),  [104]
# Theta(x) = [21.29773101]x + [14.45268292], custo ([13.13184773]),  [105]
# Theta(x) = [21.31566801]x + [14.43352449], custo ([13.12315419]),  [106]
# Theta(x) = [21.33348967]x + [14.41448927], custo ([13.11457211]),  [107]
# Theta(x) = [21.35119672]x + [14.39557645], custo ([13.10610005]),  [108]
# Theta(x) = [21.3687899]x + [14.37678526], custo ([13.0977366]),  [109]
# Theta(x) = [21.38626994]x + [14.35811491], custo ([13.08948037]),  [110]
# Theta(x) = [21.40363758]x + [14.33956462], custo ([13.08132998]),  [111]
# Theta(x) = [21.42089354]x + [14.32113362], custo ([13.07328409]),  [112]
# Theta(x) = [21.43803852]x + [14.30282114], custo ([13.06534134]),  [113]
# Theta(x) = [21.45507325]x + [14.28462643], custo ([13.05750041]),  [114]
# Theta(x) = [21.47199844]x + [14.26654872], custo ([13.04976001]),  [115]
# Theta(x) = [21.48881479]x + [14.24858726], custo ([13.04211884]),  [116]
# Theta(x) = [21.505523]x + [14.2307413], custo ([13.03457562]),  [117]
# Theta(x) = [21.52212376]x + [14.21301011], custo ([13.02712912]),  [118]
# Theta(x) = [21.53861777]x + [14.19539294], custo ([13.01977807]),  [119]
# Theta(x) = [21.55500571]x + [14.17788906], custo ([13.01252127]),  [120]
# Theta(x) = [21.57128827]x + [14.16049774], custo ([13.00535749]),  [121]
# Theta(x) = [21.58746611]x + [14.14321826], custo ([12.99828556]),  [122]
# Theta(x) = [21.60353993]x + [14.12604989], custo ([12.99130429]),  [123]
# Theta(x) = [21.61951038]x + [14.10899193], custo ([12.98441252]),  [124]
# Theta(x) = [21.63537813]x + [14.09204367], custo ([12.9776091]),  [125]
# Theta(x) = [21.65114383]x + [14.07520439], custo ([12.9708929]),  [126]
# Theta(x) = [21.66680816]x + [14.0584734], custo ([12.9642628]),  [127]
# Theta(x) = [21.68237175]x + [14.04185001], custo ([12.9577177]),  [128]
# Theta(x) = [21.69783526]x + [14.02533351], custo ([12.95125651]),  [129]
# Theta(x) = [21.71319933]x + [14.00892322], custo ([12.94487815]),  [130]
# Theta(x) = [21.72846459]x + [13.99261846], custo ([12.93858156]),  [131]
# Theta(x) = [21.7436317]x + [13.97641856], custo ([12.93236569]),  [132]
# Theta(x) = [21.75870126]x + [13.96032283], custo ([12.92622951]),  [133]
# Theta(x) = [21.77367392]x + [13.9443306], custo ([12.92017199]),  [134]
# Theta(x) = [21.7885503]x + [13.92844122], custo ([12.91419214]),  [135]
# Theta(x) = [21.80333101]x + [13.91265401], custo ([12.90828894]),  [136]
# Theta(x) = [21.81801667]x + [13.89696833], custo ([12.90246142]),  [137]
# Theta(x) = [21.83260789]x + [13.88138352], custo ([12.89670861]),  [138]
# Theta(x) = [21.84710528]x + [13.86589892], custo ([12.89102955]),  [139]
# Theta(x) = [21.86150944]x + [13.85051391], custo ([12.8854233]),  [140]
# Theta(x) = [21.87582098]x + [13.83522783], custo ([12.87988892]),  [141]
# Theta(x) = [21.89004048]x + [13.82004005], custo ([12.87442549]),  [142]
# Theta(x) = [21.90416854]x + [13.80494993], custo ([12.8690321]),  [143]
# Theta(x) = [21.91820575]x + [13.78995686], custo ([12.86370785]),  [144]
# Theta(x) = [21.93215269]x + [13.7750602], custo ([12.85845187]),  [145]
# Theta(x) = [21.94600994]x + [13.76025934], custo ([12.85326326]),  [146]
# Theta(x) = [21.95977808]x + [13.74555365], custo ([12.84814117]),  [147]
# Theta(x) = [21.97345768]x + [13.73094253], custo ([12.84308474]),  [148]
# Theta(x) = [21.98704932]x + [13.71642538], custo ([12.83809314]),  [149]
# Theta(x) = [22.00055355]x + [13.70200157], custo ([12.83316553]),  [150]
# Theta(x) = [22.01397094]x + [13.68767052], custo ([12.82830109]),  [151]
# Theta(x) = [22.02730204]x + [13.67343163], custo ([12.82349902]),  [152]
# Theta(x) = [22.04054742]x + [13.65928431], custo ([12.8187585]),  [153]
# Theta(x) = [22.05370763]x + [13.64522796], custo ([12.81407876]),  [154]
# Theta(x) = [22.0667832]x + [13.631262], custo ([12.80945902]),  [155]
# Theta(x) = [22.07977469]x + [13.61738586], custo ([12.80489849]),  [156]
# Theta(x) = [22.09268263]x + [13.60359894], custo ([12.80039644]),  [157]
# Theta(x) = [22.10550757]x + [13.58990069], custo ([12.7959521]),  [158]
# Theta(x) = [22.11825004]x + [13.57629052], custo ([12.79156474]),  [159]
# Theta(x) = [22.13091056]x + [13.56276788], custo ([12.78723362]),  [160]
# Theta(x) = [22.14348967]x + [13.5493322], custo ([12.78295803]),  [161]
# Theta(x) = [22.15598788]x + [13.53598291], custo ([12.77873725]),  [162]
# Theta(x) = [22.16840573]x + [13.52271947], custo ([12.77457058]),  [163]
# Theta(x) = [22.18074372]x + [13.50954133], custo ([12.77045733]),  [164]
# Theta(x) = [22.19300237]x + [13.49644793], custo ([12.76639681]),  [165]
# Theta(x) = [22.20518218]x + [13.48343872], custo ([12.76238834]),  [166]
# Theta(x) = [22.21728367]x + [13.47051318], custo ([12.75843126]),  [167]
# Theta(x) = [22.22930735]x + [13.45767075], custo ([12.75452492]),  [168]
# Theta(x) = [22.2412537]x + [13.44491091], custo ([12.75066865]),  [169]
# Theta(x) = [22.25312323]x + [13.43223313], custo ([12.74686182]),  [170]
# Theta(x) = [22.26491643]x + [13.41963687], custo ([12.74310379]),  [171]
# Theta(x) = [22.27663379]x + [13.40712161], custo ([12.73939394]),  [172]
# Theta(x) = [22.2882758]x + [13.39468683], custo ([12.73573165]),  [173]
# Theta(x) = [22.29984294]x + [13.38233202], custo ([12.73211631]),  [174]
# Theta(x) = [22.3113357]x + [13.37005666], custo ([12.72854732]),  [175]
# Theta(x) = [22.32275456]x + [13.35786024], custo ([12.72502409]),  [176]
# Theta(x) = [22.33409998]x + [13.34574224], custo ([12.72154602]),  [177]
# Theta(x) = [22.34537245]x + [13.33370218], custo ([12.71811254]),  [178]
# Theta(x) = [22.35657243]x + [13.32173954], custo ([12.71472308]),  [179]
# Theta(x) = [22.36770038]x + [13.30985383], custo ([12.71137707]),  [180]
# Theta(x) = [22.37875677]x + [13.29804455], custo ([12.70807395]),  [181]
# Theta(x) = [22.38974206]x + [13.28631121], custo ([12.70481318]),  [182]
# Theta(x) = [22.40065671]x + [13.27465332], custo ([12.70159422]),  [183]
# Theta(x) = [22.41150118]x + [13.26307041], custo ([12.69841652]),  [184]
# Theta(x) = [22.4222759]x + [13.25156197], custo ([12.69527956]),  [185]
# Theta(x) = [22.43298134]x + [13.24012755], custo ([12.69218282]),  [186]
# Theta(x) = [22.44361793]x + [13.22876666], custo ([12.68912577]),  [187]
# Theta(x) = [22.45418612]x + [13.21747882], custo ([12.68610792]),  [188]
# Theta(x) = [22.46468636]x + [13.20626357], custo ([12.68312876]),  [189]
# Theta(x) = [22.47511907]x + [13.19512045], custo ([12.68018778]),  [190]
# Theta(x) = [22.48548469]x + [13.18404898], custo ([12.67728452]),  [191]
# Theta(x) = [22.49578365]x + [13.17304871], custo ([12.67441847]),  [192]
# Theta(x) = [22.50601638]x + [13.16211918], custo ([12.67158916]),  [193]
# Theta(x) = [22.51618331]x + [13.15125993], custo ([12.66879613]),  [194]
# Theta(x) = [22.52628486]x + [13.14047051], custo ([12.6660389]),  [195]
# Theta(x) = [22.53632145]x + [13.12975048], custo ([12.66331702]),  [196]
# Theta(x) = [22.5462935]x + [13.11909938], custo ([12.66063003]),  [197]
# Theta(x) = [22.55620142]x + [13.10851678], custo ([12.65797749]),  [198]
# Theta(x) = [22.56604563]x + [13.09800223], custo ([12.65535896]),  [199]
# Theta(x) = [22.57582653]x + [13.0875553], custo ([12.652774]),  [200]
# Theta(x) = [22.58554453]x + [13.07717554], custo ([12.65022217]),  [201]
# Theta(x) = [22.59520004]x + [13.06686254], custo ([12.64770306]),  [202]
# Theta(x) = [22.60479346]x + [13.05661585], custo ([12.64521625]),  [203]
# Theta(x) = [22.61432519]x + [13.04643506], custo ([12.64276131]),  [204]
# Theta(x) = [22.62379562]x + [13.03631974], custo ([12.64033785]),  [205]
# Theta(x) = [22.63320516]x + [13.02626946], custo ([12.63794546]),  [206]
# Theta(x) = [22.64255418]x + [13.01628382], custo ([12.63558373]),  [207]
# Theta(x) = [22.65184308]x + [13.00636239], custo ([12.63325229]),  [208]
# Theta(x) = [22.66107225]x + [12.99650476], custo ([12.63095073]),  [209]
# Theta(x) = [22.67024206]x + [12.98671052], custo ([12.62867868]),  [210]
# Theta(x) = [22.67935292]x + [12.97697926], custo ([12.62643576]),  [211]
# Theta(x) = [22.68840518]x + [12.96731059], custo ([12.62422159]),  [212]
# Theta(x) = [22.69739923]x + [12.95770409], custo ([12.6220358]),  [213]
# Theta(x) = [22.70633544]x + [12.94815936], custo ([12.61987804]),  [214]
# Theta(x) = [22.71521418]x + [12.93867602], custo ([12.61774794]),  [215]
# Theta(x) = [22.72403583]x + [12.92925366], custo ([12.61564515]),  [216]
# Theta(x) = [22.73280075]x + [12.91989189], custo ([12.61356932]),  [217]
# Theta(x) = [22.74150931]x + [12.91059032], custo ([12.6115201]),  [218]
# Theta(x) = [22.75016187]x + [12.90134857], custo ([12.60949715]),  [219]
# Theta(x) = [22.75875878]x + [12.89216625], custo ([12.60750013]),  [220]
# Theta(x) = [22.76730041]x + [12.88304297], custo ([12.60552871]),  [221]
# Theta(x) = [22.77578711]x + [12.87397837], custo ([12.60358257]),  [222]
# Theta(x) = [22.78421923]x + [12.86497206], custo ([12.60166138]),  [223]
# Theta(x) = [22.79259714]x + [12.85602366], custo ([12.59976482]),  [224]
# Theta(x) = [22.80092116]x + [12.84713281], custo ([12.59789257]),  [225]
# Theta(x) = [22.80919166]x + [12.83829913], custo ([12.59604432]),  [226]
# Theta(x) = [22.81740897]x + [12.82952226], custo ([12.59421977]),  [227]
# Theta(x) = [22.82557344]x + [12.82080183], custo ([12.59241861]),  [228]
# Theta(x) = [22.83368541]x + [12.81213748], custo ([12.59064054]),  [229]
# Theta(x) = [22.84174521]x + [12.80352884], custo ([12.58888526]),  [230]
# Theta(x) = [22.84975318]x + [12.79497557], custo ([12.58715249]),  [231]
# Theta(x) = [22.85770966]x + [12.78647729], custo ([12.58544193]),  [232]
# Theta(x) = [22.86561497]x + [12.77803367], custo ([12.5837533]),  [233]
# Theta(x) = [22.87346944]x + [12.76964435], custo ([12.58208632]),  [234]
# Theta(x) = [22.8812734]x + [12.76130897], custo ([12.58044071]),  [235]
# Theta(x) = [22.88902718]x + [12.7530272], custo ([12.57881619]),  [236]
# Theta(x) = [22.8967311]x + [12.74479868], custo ([12.57721251]),  [237]
# Theta(x) = [22.90438548]x + [12.73662308], custo ([12.57562938]),  [238]
# Theta(x) = [22.91199063]x + [12.72850005], custo ([12.57406655]),  [239]
# Theta(x) = [22.91954688]x + [12.72042926], custo ([12.57252375]),  [240]
# Theta(x) = [22.92705453]x + [12.71241037], custo ([12.57100073]),  [241]
# Theta(x) = [22.93451391]x + [12.70444304], custo ([12.56949723]),  [242]
# Theta(x) = [22.94192532]x + [12.69652695], custo ([12.56801302]),  [243]
# Theta(x) = [22.94928907]x + [12.68866177], custo ([12.56654782]),  [244]
# Theta(x) = [22.95660546]x + [12.68084717], custo ([12.56510142]),  [245]
# Theta(x) = [22.9638748]x + [12.67308282], custo ([12.56367355]),  [246]
# Theta(x) = [22.9710974]x + [12.66536839], custo ([12.56226399]),  [247]
# Theta(x) = [22.97827355]x + [12.65770358], custo ([12.5608725]),  [248]
# Theta(x) = [22.98540356]x + [12.65008806], custo ([12.55949885]),  [249]
# Theta(x) = [22.99248771]x + [12.64252151], custo ([12.55814281]),  [250]
# Theta(x) = [22.99952631]x + [12.63500362], custo ([12.55680416]),  [251]
# Theta(x) = [23.00651965]x + [12.62753407], custo ([12.55548266]),  [252]
# Theta(x) = [23.01346801]x + [12.62011255], custo ([12.55417811]),  [253]
# Theta(x) = [23.02037169]x + [12.61273877], custo ([12.55289028]),  [254]
# Theta(x) = [23.02723097]x + [12.6054124], custo ([12.55161896]),  [255]
# Theta(x) = [23.03404615]x + [12.59813314], custo ([12.55036394]),  [256]
# Theta(x) = [23.0408175]x + [12.5909007], custo ([12.54912501]),  [257]
# Theta(x) = [23.04754531]x + [12.58371476], custo ([12.54790196]),  [258]
# Theta(x) = [23.05422985]x + [12.57657503], custo ([12.54669459]),  [259]
# Theta(x) = [23.0608714]x + [12.56948122], custo ([12.5455027]),  [260]
# Theta(x) = [23.06747025]x + [12.56243302], custo ([12.54432609]),  [261]
# Theta(x) = [23.07402666]x + [12.55543015], custo ([12.54316457]),  [262]
# Theta(x) = [23.08054091]x + [12.54847232], custo ([12.54201793]),  [263]
# Theta(x) = [23.08701327]x + [12.54155922], custo ([12.540886]),  [264]
# Theta(x) = [23.093444]x + [12.53469058], custo ([12.53976857]),  [265]
# Theta(x) = [23.09983338]x + [12.52786612], custo ([12.53866547]),  [266]
# Theta(x) = [23.10618168]x + [12.52108553], custo ([12.53757652]),  [267]
# Theta(x) = [23.11248915]x + [12.51434855], custo ([12.53650152]),  [268]
# Theta(x) = [23.11875606]x + [12.5076549], custo ([12.53544031]),  [269]
# Theta(x) = [23.12498267]x + [12.50100429], custo ([12.53439269]),  [270]
# Theta(x) = [23.13116924]x + [12.49439645], custo ([12.53335851]),  [271]
# Theta(x) = [23.13731602]x + [12.48783109], custo ([12.53233759]),  [272]
# Theta(x) = [23.14342328]x + [12.48130796], custo ([12.53132976]),  [273]
# Theta(x) = [23.14949126]x + [12.47482678], custo ([12.53033485]),  [274]
# Theta(x) = [23.15552022]x + [12.46838728], custo ([12.52935269]),  [275]
# Theta(x) = [23.16151041]x + [12.46198918], custo ([12.52838312]),  [276]
# Theta(x) = [23.16746208]x + [12.45563223], custo ([12.52742598]),  [277]
# Theta(x) = [23.17337548]x + [12.44931616], custo ([12.52648111]),  [278]
# Theta(x) = [23.17925085]x + [12.44304071], custo ([12.52554836]),  [279]
# Theta(x) = [23.18508844]x + [12.43680561], custo ([12.52462756]),  [280]
# Theta(x) = [23.19088849]x + [12.4306106], custo ([12.52371857]),  [281]
# Theta(x) = [23.19665124]x + [12.42445544], custo ([12.52282123]),  [282]
# Theta(x) = [23.20237693]x + [12.41833986], custo ([12.5219354]),  [283]
# Theta(x) = [23.2080658]x + [12.4122636], custo ([12.52106092]),  [284]
# Theta(x) = [23.21371809]x + [12.40622642], custo ([12.52019766]),  [285]
# Theta(x) = [23.21933403]x + [12.40022806], custo ([12.51934545]),  [286]
# Theta(x) = [23.22491385]x + [12.39426827], custo ([12.51850418]),  [287]
# Theta(x) = [23.2304578]x + [12.38834681], custo ([12.51767369]),  [288]
# Theta(x) = [23.23596609]x + [12.38246343], custo ([12.51685385]),  [289]
# Theta(x) = [23.24143896]x + [12.37661788], custo ([12.51604451]),  [290]
# Theta(x) = [23.24687664]x + [12.37080993], custo ([12.51524556]),  [291]
# Theta(x) = [23.25227935]x + [12.36503932], custo ([12.51445684]),  [292]
# Theta(x) = [23.25764732]x + [12.35930582], custo ([12.51367824]),  [293]
# Theta(x) = [23.26298076]x + [12.35360919], custo ([12.51290962]),  [294]
# Theta(x) = [23.26827991]x + [12.3479492], custo ([12.51215085]),  [295]
# Theta(x) = [23.27354498]x + [12.3423256], custo ([12.51140181]),  [296]
# Theta(x) = [23.2787762]x + [12.33673817], custo ([12.51066237]),  [297]
# Theta(x) = [23.28397377]x + [12.33118666], custo ([12.50993241]),  [298]
# Theta(x) = [23.28913792]x + [12.32567086], custo ([12.50921181]),  [299]
# Theta(x) = [23.29426886]x + [12.32019052], custo ([12.50850045]),  [300]
# Theta(x) = [23.29936681]x + [12.31474543], custo ([12.50779821]),  [301]
# Theta(x) = [23.30443197]x + [12.30933536], custo ([12.50710497]),  [302]
# Theta(x) = [23.30946456]x + [12.30396007], custo ([12.50642062]),  [303]
# Theta(x) = [23.31446479]x + [12.29861935], custo ([12.50574504]),  [304]
# Theta(x) = [23.31943286]x + [12.29331298], custo ([12.50507812]),  [305]
# Theta(x) = [23.32436899]x + [12.28804073], custo ([12.50441975]),  [306]
# Theta(x) = [23.32927337]x + [12.28280238], custo ([12.50376982]),  [307]
# Theta(x) = [23.33414621]x + [12.27759772], custo ([12.50312823]),  [308]
# Theta(x) = [23.33898772]x + [12.27242653], custo ([12.50249486]),  [309]
# Theta(x) = [23.3437981]x + [12.26728859], custo ([12.50186961]),  [310]
# Theta(x) = [23.34857754]x + [12.26218369], custo ([12.50125237]),  [311]
# Theta(x) = [23.35332624]x + [12.25711162], custo ([12.50064305]),  [312]
# Theta(x) = [23.35804441]x + [12.25207217], custo ([12.50004154]),  [313]
# Theta(x) = [23.36273224]x + [12.24706513], custo ([12.49944774]),  [314]
# Theta(x) = [23.36738992]x + [12.24209028], custo ([12.49886155]),  [315]
# Theta(x) = [23.37201765]x + [12.23714743], custo ([12.49828288]),  [316]
# Theta(x) = [23.37661562]x + [12.23223636], custo ([12.49771163]),  [317]
# Theta(x) = [23.38118402]x + [12.22735687], custo ([12.4971477]),  [318]
# Theta(x) = [23.38572304]x + [12.22250876], custo ([12.496591]),  [319]
# Theta(x) = [23.39023288]x + [12.21769182], custo ([12.49604143]),  [320]
# Theta(x) = [23.39471371]x + [12.21290587], custo ([12.49549891]),  [321]
# Theta(x) = [23.39916573]x + [12.20815069], custo ([12.49496335]),  [322]
# Theta(x) = [23.40358912]x + [12.20342609], custo ([12.49443465]),  [323]
# Theta(x) = [23.40798407]x + [12.19873187], custo ([12.49391273]),  [324]
# Theta(x) = [23.41235075]x + [12.19406784], custo ([12.49339751]),  [325]
# Theta(x) = [23.41668935]x + [12.1894338], custo ([12.49288888]),  [326]
# Theta(x) = [23.42100005]x + [12.18482956], custo ([12.49238678]),  [327]
# Theta(x) = [23.42528303]x + [12.18025493], custo ([12.49189111]),  [328]
# Theta(x) = [23.42953847]x + [12.17570971], custo ([12.4914018]),  [329]
# Theta(x) = [23.43376654]x + [12.17119373], custo ([12.49091876]),  [330]
# Theta(x) = [23.43796743]x + [12.16670679], custo ([12.49044192]),  [331]
# Theta(x) = [23.4421413]x + [12.1622487], custo ([12.48997119]),  [332]
# Theta(x) = [23.44628833]x + [12.15781927], custo ([12.48950649]),  [333]
# Theta(x) = [23.45040869]x + [12.15341834], custo ([12.48904775]),  [334]
# Theta(x) = [23.45450255]x + [12.1490457], custo ([12.48859489]),  [335]
# Theta(x) = [23.45857009]x + [12.14470118], custo ([12.48814783]),  [336]
# Theta(x) = [23.46261147]x + [12.14038461], custo ([12.48770651]),  [337]
# Theta(x) = [23.46662686]x + [12.13609578], custo ([12.48727085]),  [338]
# Theta(x) = [23.47061643]x + [12.13183454], custo ([12.48684077]),  [339]
# Theta(x) = [23.47458035]x + [12.12760071], custo ([12.4864162]),  [340]
# Theta(x) = [23.47851877]x + [12.12339409], custo ([12.48599708]),  [341]
# Theta(x) = [23.48243187]x + [12.11921453], custo ([12.48558333]),  [342]
# Theta(x) = [23.4863198]x + [12.11506185], custo ([12.48517488]),  [343]
# Theta(x) = [23.49018273]x + [12.11093587], custo ([12.48477167]),  [344]
# Theta(x) = [23.49402082]x + [12.10683643], custo ([12.48437363]),  [345]
# Theta(x) = [23.49783423]x + [12.10276334], custo ([12.4839807]),  [346]
# Theta(x) = [23.50162312]x + [12.09871645], custo ([12.4835928]),  [347]
# Theta(x) = [23.50538764]x + [12.09469558], custo ([12.48320987]),  [348]
# Theta(x) = [23.50912795]x + [12.09070057], custo ([12.48283185]),  [349]
# Theta(x) = [23.51284421]x + [12.08673126], custo ([12.48245868]),  [350]
# Theta(x) = [23.51653657]x + [12.08278746], custo ([12.48209029]),  [351]
# Theta(x) = [23.52020519]x + [12.07886903], custo ([12.48172663]),  [352]
# Theta(x) = [23.52385022]x + [12.07497579], custo ([12.48136762]),  [353]
# Theta(x) = [23.5274718]x + [12.07110759], custo ([12.48101322]),  [354]
# Theta(x) = [23.5310701]x + [12.06726427], custo ([12.48066336]),  [355]
# Theta(x) = [23.53464526]x + [12.06344566], custo ([12.48031799]),  [356]
# Theta(x) = [23.53819743]x + [12.05965161], custo ([12.47997705]),  [357]
# Theta(x) = [23.54172675]x + [12.05588196], custo ([12.47964048]),  [358]
# Theta(x) = [23.54523338]x + [12.05213654], custo ([12.47930822]),  [359]
# Theta(x) = [23.54871746]x + [12.04841522], custo ([12.47898022]),  [360]
# Theta(x) = [23.55217913]x + [12.04471782], custo ([12.47865642]),  [361]
# Theta(x) = [23.55561854]x + [12.0410442], custo ([12.47833678]),  [362]
# Theta(x) = [23.55903584]x + [12.0373942], custo ([12.47802124]),  [363]
# Theta(x) = [23.56243116]x + [12.03376768], custo ([12.47770974]),  [364]
# Theta(x) = [23.56580464]x + [12.03016448], custo ([12.47740223]),  [365]
# Theta(x) = [23.56915644]x + [12.02658444], custo ([12.47709866]),  [366]
# Theta(x) = [23.57248667]x + [12.02302743], custo ([12.47679899]),  [367]
# Theta(x) = [23.57579549]x + [12.0194933], custo ([12.47650316]),  [368]
# Theta(x) = [23.57908304]x + [12.01598189], custo ([12.47621112]),  [369]
# Theta(x) = [23.58234944]x + [12.01249306], custo ([12.47592283]),  [370]
# Theta(x) = [23.58559484]x + [12.00902666], custo ([12.47563823]),  [371]
# Theta(x) = [23.58881937]x + [12.00558256], custo ([12.47535728]),  [372]
# Theta(x) = [23.59202316]x + [12.00216061], custo ([12.47507993]),  [373]
# Theta(x) = [23.59520635]x + [11.99876066], custo ([12.47480614]),  [374]
# Theta(x) = [23.59836907]x + [11.99538257], custo ([12.47453586]),  [375]
# Theta(x) = [23.60151145]x + [11.99202621], custo ([12.47426904]),  [376]
# Theta(x) = [23.60463362]x + [11.98869143], custo ([12.47400564]),  [377]
# Theta(x) = [23.60773572]x + [11.9853781], custo ([12.47374562]),  [378]
# Theta(x) = [23.61081786]x + [11.98208607], custo ([12.47348894]),  [379]
# Theta(x) = [23.61388019]x + [11.97881522], custo ([12.47323554]),  [380]
# Theta(x) = [23.61692283]x + [11.97556539], custo ([12.47298539]),  [381]
# Theta(x) = [23.61994589]x + [11.97233647], custo ([12.47273845]),  [382]
# Theta(x) = [23.62294952]x + [11.96912831], custo ([12.47249468]),  [383]
# Theta(x) = [23.62593383]x + [11.96594078], custo ([12.47225403]),  [384]
# Theta(x) = [23.62889895]x + [11.96277375], custo ([12.47201646]),  [385]
# Theta(x) = [23.63184501]x + [11.95962708], custo ([12.47178194]),  [386]
# Theta(x) = [23.63477212]x + [11.95650065], custo ([12.47155043]),  [387]
# Theta(x) = [23.6376804]x + [11.95339433], custo ([12.47132189]),  [388]
# Theta(x) = [23.64056999]x + [11.95030798], custo ([12.47109627]),  [389]
# Theta(x) = [23.64344099]x + [11.94724147], custo ([12.47087355]),  [390]
# Theta(x) = [23.64629352]x + [11.94419469], custo ([12.47065368]),  [391]
# Theta(x) = [23.64912772]x + [11.9411675], custo ([12.47043664]),  [392]
# Theta(x) = [23.65194369]x + [11.93815978], custo ([12.47022237]),  [393]
# Theta(x) = [23.65474155]x + [11.9351714], custo ([12.47001085]),  [394]
# Theta(x) = [23.65752142]x + [11.93220223], custo ([12.46980204]),  [395]
# Theta(x) = [23.66028341]x + [11.92925216], custo ([12.46959591]),  [396]
# Theta(x) = [23.66302764]x + [11.92632106], custo ([12.46939243]),  [397]
# Theta(x) = [23.66575423]x + [11.92340881], custo ([12.46919155]),  [398]
# Theta(x) = [23.66846328]x + [11.92051529], custo ([12.46899324]),  [399]
# Theta(x) = [23.6711549]x + [11.91764037], custo ([12.46879748]),  [400]
# Theta(x) = [23.67382922]x + [11.91478395], custo ([12.46860423]),  [401]
# Theta(x) = [23.67648635]x + [11.91194589], custo ([12.46841346]),  [402]
# Theta(x) = [23.67912638]x + [11.90912608], custo ([12.46822513]),  [403]
# Theta(x) = [23.68174944]x + [11.9063244], custo ([12.46803921]),  [404]
# Theta(x) = [23.68435563]x + [11.90354074], custo ([12.46785568]),  [405]
# Theta(x) = [23.68694506]x + [11.90077498], custo ([12.46767451]),  [406]
# Theta(x) = [23.68951784]x + [11.89802701], custo ([12.46749565]),  [407]
# Theta(x) = [23.69207407]x + [11.89529671], custo ([12.46731909]),  [408]
# Theta(x) = [23.69461387]x + [11.89258397], custo ([12.46714479]),  [409]
# Theta(x) = [23.69713733]x + [11.88988867], custo ([12.46697273]),  [410]
# Theta(x) = [23.69964457]x + [11.8872107], custo ([12.46680287]),  [411]
# Theta(x) = [23.70213568]x + [11.88454996], custo ([12.46663519]),  [412]
# Theta(x) = [23.70461077]x + [11.88190632], custo ([12.46646966]),  [413]
# Theta(x) = [23.70706995]x + [11.87927969], custo ([12.46630625]),  [414]
# Theta(x) = [23.70951331]x + [11.87666994], custo ([12.46614493]),  [415]
# Theta(x) = [23.71194096]x + [11.87407698], custo ([12.46598569]),  [416]
# Theta(x) = [23.714353]x + [11.8715007], custo ([12.46582848]),  [417]
# Theta(x) = [23.71674953]x + [11.86894098], custo ([12.46567329]),  [418]
# Theta(x) = [23.71913065]x + [11.86639772], custo ([12.46552009]),  [419]
# Theta(x) = [23.72149645]x + [11.86387081], custo ([12.46536886]),  [420]
# Theta(x) = [23.72384704]x + [11.86136016], custo ([12.46521956]),  [421]
# Theta(x) = [23.72618252]x + [11.85886565], custo ([12.46507218]),  [422]
# Theta(x) = [23.72850297]x + [11.85638718], custo ([12.46492668]),  [423]
# Theta(x) = [23.73080851]x + [11.85392465], custo ([12.46478306]),  [424]
# Theta(x) = [23.73309921]x + [11.85147796], custo ([12.46464127]),  [425]
# Theta(x) = [23.73537519]x + [11.849047], custo ([12.4645013]),  [426]
# Theta(x) = [23.73763653]x + [11.84663167], custo ([12.46436312]),  [427]
# Theta(x) = [23.73988333]x + [11.84423187], custo ([12.46422672]),  [428]
# Theta(x) = [23.74211568]x + [11.84184751], custo ([12.46409207]),  [429]
# Theta(x) = [23.74433368]x + [11.83947848], custo ([12.46395914]),  [430]
# Theta(x) = [23.74653741]x + [11.83712469], custo ([12.46382791]),  [431]
# Theta(x) = [23.74872697]x + [11.83478603], custo ([12.46369837]),  [432]
# Theta(x) = [23.75090245]x + [11.83246241], custo ([12.46357049]),  [433]
# Theta(x) = [23.75306394]x + [11.83015373], custo ([12.46344425]),  [434]
# Theta(x) = [23.75521153]x + [11.8278599], custo ([12.46331963]),  [435]
# Theta(x) = [23.75734531]x + [11.82558082], custo ([12.4631966]),  [436]
# Theta(x) = [23.75946537]x + [11.82331639], custo ([12.46307515]),  [437]
# Theta(x) = [23.7615718]x + [11.82106653], custo ([12.46295526]),  [438]
# Theta(x) = [23.76366468]x + [11.81883114], custo ([12.4628369]),  [439]
# Theta(x) = [23.7657441]x + [11.81661012], custo ([12.46272007]),  [440]
# Theta(x) = [23.76781015]x + [11.81440338], custo ([12.46260473]),  [441]
# Theta(x) = [23.76986291]x + [11.81221083], custo ([12.46249087]),  [442]
# Theta(x) = [23.77190247]x + [11.81003239], custo ([12.46237847]),  [443]
# Theta(x) = [23.77392892]x + [11.80786795], custo ([12.46226751]),  [444]
# Theta(x) = [23.77594233]x + [11.80571743], custo ([12.46215797]),  [445]
# Theta(x) = [23.7779428]x + [11.80358074], custo ([12.46204984]),  [446]
# Theta(x) = [23.7799304]x + [11.80145779], custo ([12.46194309]),  [447]
# Theta(x) = [23.78190523]x + [11.79934849], custo ([12.46183771]),  [448]
# Theta(x) = [23.78386735]x + [11.79725276], custo ([12.46173368]),  [449]
# Theta(x) = [23.78581685]x + [11.7951705], custo ([12.46163099]),  [450]
# Theta(x) = [23.78775382]x + [11.79310164], custo ([12.46152961]),  [451]
# Theta(x) = [23.78967833]x + [11.79104608], custo ([12.46142953]),  [452]
# Theta(x) = [23.79159047]x + [11.78900373], custo ([12.46133074]),  [453]
# Theta(x) = [23.79349031]x + [11.78697452], custo ([12.46123321]),  [454]
# Theta(x) = [23.79537793]x + [11.78495836], custo ([12.46113693]),  [455]
# Theta(x) = [23.79725341]x + [11.78295517], custo ([12.46104189]),  [456]
# Theta(x) = [23.79911684]x + [11.78096485], custo ([12.46094806]),  [457]
# Theta(x) = [23.80096828]x + [11.77898734], custo ([12.46085544]),  [458]
# Theta(x) = [23.80280781]x + [11.77702254], custo ([12.460764]),  [459]
# Theta(x) = [23.80463552]x + [11.77507038], custo ([12.46067374]),  [460]
# Theta(x) = [23.80645147]x + [11.77313077], custo ([12.46058464]),  [461]
# Theta(x) = [23.80825574]x + [11.77120363], custo ([12.46049667]),  [462]
# Theta(x) = [23.81004841]x + [11.76928889], custo ([12.46040984]),  [463]
# Theta(x) = [23.81182956]x + [11.76738646], custo ([12.46032412]),  [464]
# Theta(x) = [23.81359925]x + [11.76549626], custo ([12.46023949]),  [465]
# Theta(x) = [23.81535755]x + [11.76361822], custo ([12.46015595]),  [466]
# Theta(x) = [23.81710456]x + [11.76175226], custo ([12.46007349]),  [467]
# Theta(x) = [23.81884032]x + [11.75989829], custo ([12.45999208]),  [468]
# Theta(x) = [23.82056493]x + [11.75805625], custo ([12.45991171]),  [469]
# Theta(x) = [23.82227844]x + [11.75622605], custo ([12.45983237]),  [470]
# Theta(x) = [23.82398094]x + [11.75440763], custo ([12.45975405]),  [471]
# Theta(x) = [23.82567249]x + [11.75260089], custo ([12.45967674]),  [472]
# Theta(x) = [23.82735316]x + [11.75080578], custo ([12.45960041]),  [473]
# Theta(x) = [23.82902302]x + [11.74902221], custo ([12.45952507]),  [474]
# Theta(x) = [23.83068214]x + [11.7472501], custo ([12.45945069]),  [475]
# Theta(x) = [23.8323306]x + [11.7454894], custo ([12.45937726]),  [476]
# Theta(x) = [23.83396845]x + [11.74374001], custo ([12.45930478]),  [477]
# Theta(x) = [23.83559577]x + [11.74200188], custo ([12.45923322]),  [478]
# Theta(x) = [23.83721263]x + [11.74027492], custo ([12.45916258]),  [479]
# Theta(x) = [23.83881909]x + [11.73855907], custo ([12.45909285]),  [480]
# Theta(x) = [23.84041522]x + [11.73685426], custo ([12.45902401]),  [481]
# Theta(x) = [23.84200108]x + [11.7351604], custo ([12.45895606]),  [482]
# Theta(x) = [23.84357675]x + [11.73347744], custo ([12.45888897]),  [483]
# Theta(x) = [23.84514228]x + [11.7318053], custo ([12.45882275]),  [484]
# Theta(x) = [23.84669775]x + [11.73014391], custo ([12.45875737]),  [485]
# Theta(x) = [23.84824321]x + [11.72849321], custo ([12.45869283]),  [486]
# Theta(x) = [23.84977874]x + [11.72685313], custo ([12.45862912]),  [487]
# Theta(x) = [23.85130439]x + [11.72522359], custo ([12.45856623]),  [488]
# Theta(x) = [23.85282023]x + [11.72360452], custo ([12.45850414]),  [489]
# Theta(x) = [23.85432632]x + [11.72199587], custo ([12.45844285]),  [490]
# Theta(x) = [23.85582273]x + [11.72039757], custo ([12.45838234]),  [491]
# Theta(x) = [23.85730951]x + [11.71880954], custo ([12.45832261]),  [492]
# Theta(x) = [23.85878673]x + [11.71723173], custo ([12.45826365]),  [493]
# Theta(x) = [23.86025446]x + [11.71566406], custo ([12.45820544]),  [494]
# Theta(x) = [23.86171274]x + [11.71410647], custo ([12.45814798]),  [495]
# Theta(x) = [23.86316165]x + [11.7125589], custo ([12.45809125]),  [496]
# Theta(x) = [23.86460124]x + [11.71102128], custo ([12.45803526]),  [497]
# Theta(x) = [23.86603157]x + [11.70949355], custo ([12.45797998]),  [498]
# Theta(x) = [23.8674527]x + [11.70797565], custo ([12.4579254]),  [499]
# Theta(x) = [23.8688647]x + [11.7064675], custo ([12.45787153]),  [500]
# Theta(x) = [23.87026762]x + [11.70496905], custo ([12.45781835]),  [501]
# Theta(x) = [23.87166151]x + [11.70348024], custo ([12.45776585]),  [502]
# Theta(x) = [23.87304644]x + [11.702001], custo ([12.45771402]),  [503]
# Theta(x) = [23.87442246]x + [11.70053128], custo ([12.45766286]),  [504]
# Theta(x) = [23.87578964]x + [11.69907101], custo ([12.45761236]),  [505]
# Theta(x) = [23.87714802]x + [11.69762012], custo ([12.4575625]),  [506]
# Theta(x) = [23.87849767]x + [11.69617857], custo ([12.45751328]),  [507]
# Theta(x) = [23.87983864]x + [11.69474629], custo ([12.45746469]),  [508]
# Theta(x) = [23.88117099]x + [11.69332322], custo ([12.45741672]),  [509]
# Theta(x) = [23.88249476]x + [11.6919093], custo ([12.45736937]),  [510]
# Theta(x) = [23.88381003]x + [11.69050447], custo ([12.45732263]),  [511]
# Theta(x) = [23.88511684]x + [11.68910867], custo ([12.45727648]),  [512]
# Theta(x) = [23.88641524]x + [11.68772185], custo ([12.45723093]),  [513]
# Theta(x) = [23.88770529]x + [11.68634395], custo ([12.45718596]),  [514]
# Theta(x) = [23.88898705]x + [11.68497491], custo ([12.45714157]),  [515]
# Theta(x) = [23.89026057]x + [11.68361468], custo ([12.45709775]),  [516]
# Theta(x) = [23.89152589]x + [11.68226319], custo ([12.45705449]),  [517]
# Theta(x) = [23.89278308]x + [11.68092039], custo ([12.45701178]),  [518]
# Theta(x) = [23.89403219]x + [11.67958623], custo ([12.45696962]),  [519]
# Theta(x) = [23.89527326]x + [11.67826065], custo ([12.456928]),  [520]
# Theta(x) = [23.89650635]x + [11.67694359], custo ([12.45688692]),  [521]
# Theta(x) = [23.89773151]x + [11.675635], custo ([12.45684636]),  [522]
# Theta(x) = [23.89894879]x + [11.67433483], custo ([12.45680632]),  [523]
# Theta(x) = [23.90015825]x + [11.67304301], custo ([12.45676679]),  [524]
# Theta(x) = [23.90135993]x + [11.67175951], custo ([12.45672777]),  [525]
# Theta(x) = [23.90255387]x + [11.67048426], custo ([12.45668926]),  [526]
# Theta(x) = [23.90374015]x + [11.6692172], custo ([12.45665123]),  [527]
# Theta(x) = [23.90491879]x + [11.6679583], custo ([12.45661369]),  [528]
# Theta(x) = [23.90608985]x + [11.66670749], custo ([12.45657664]),  [529]
# Theta(x) = [23.90725339]x + [11.66546473], custo ([12.45654006]),  [530]
# Theta(x) = [23.90840944]x + [11.66422996], custo ([12.45650394]),  [531]
# Theta(x) = [23.90955805]x + [11.66300313], custo ([12.4564683]),  [532]
# Theta(x) = [23.91069928]x + [11.66178418], custo ([12.4564331]),  [533]
# Theta(x) = [23.91183318]x + [11.66057308], custo ([12.45639836]),  [534]
# Theta(x) = [23.91295978]x + [11.65936976], custo ([12.45636407]),  [535]
# Theta(x) = [23.91407913]x + [11.65817419], custo ([12.45633021]),  [536]
# Theta(x) = [23.91519129]x + [11.6569863], custo ([12.45629679]),  [537]
# Theta(x) = [23.91629629]x + [11.65580605], custo ([12.4562638]),  [538]
# Theta(x) = [23.91739419]x + [11.65463339], custo ([12.45623123]),  [539]
# Theta(x) = [23.91848503]x + [11.65346827], custo ([12.45619907]),  [540]
# Theta(x) = [23.91956885]x + [11.65231064], custo ([12.45616733]),  [541]
# Theta(x) = [23.92064571]x + [11.65116046], custo ([12.456136]),  [542]
# Theta(x) = [23.92171564]x + [11.65001767], custo ([12.45610507]),  [543]
# Theta(x) = [23.92277869]x + [11.64888223], custo ([12.45607453]),  [544]
# Theta(x) = [23.9238349]x + [11.6477541], custo ([12.45604439]),  [545]
# Theta(x) = [23.92488432]x + [11.64663321], custo ([12.45601463]),  [546]
# Theta(x) = [23.92592699]x + [11.64551954], custo ([12.45598526]),  [547]
# Theta(x) = [23.92696296]x + [11.64441303], custo ([12.45595626]),  [548]
# Theta(x) = [23.92799227]x + [11.64331363], custo ([12.45592763]),  [549]
# Theta(x) = [23.92901495]x + [11.64222131], custo ([12.45589937]),  [550]
# Theta(x) = [23.93003106]x + [11.64113601], custo ([12.45587147]),  [551]
# Theta(x) = [23.93104064]x + [11.64005768], custo ([12.45584393]),  [552]
# Theta(x) = [23.93204372]x + [11.6389863], custo ([12.45581674]),  [553]
# Theta(x) = [23.93304035]x + [11.6379218], custo ([12.4557899]),  [554]
# Theta(x) = [23.93403058]x + [11.63686414], custo ([12.45576341]),  [555]
# Theta(x) = [23.93501443]x + [11.63581329], custo ([12.45573725]),  [556]
# Theta(x) = [23.93599196]x + [11.6347692], custo ([12.45571143]),  [557]
# Theta(x) = [23.9369632]x + [11.63373182], custo ([12.45568594]),  [558]
# Theta(x) = [23.9379282]x + [11.63270111], custo ([12.45566078]),  [559]
# Theta(x) = [23.93888699]x + [11.63167703], custo ([12.45563594]),  [560]
# Theta(x) = [23.93983962]x + [11.63065953], custo ([12.45561142]),  [561]
# Theta(x) = [23.94078612]x + [11.62964858], custo ([12.45558721]),  [562]
# Theta(x) = [23.94172653]x + [11.62864413], custo ([12.45556332]),  [563]
# Theta(x) = [23.9426609]x + [11.62764614], custo ([12.45553973]),  [564]
# Theta(x) = [23.94358925]x + [11.62665457], custo ([12.45551644]),  [565]
# Theta(x) = [23.94451164]x + [11.62566937], custo ([12.45549345]),  [566]
# Theta(x) = [23.9454281]x + [11.62469051], custo ([12.45547076]),  [567]
# Theta(x) = [23.94633866]x + [11.62371794], custo ([12.45544835]),  [568]
# Theta(x) = [23.94724337]x + [11.62275163], custo ([12.45542624]),  [569]
# Theta(x) = [23.94814226]x + [11.62179153], custo ([12.4554044]),  [570]
# Theta(x) = [23.94903536]x + [11.6208376], custo ([12.45538285]),  [571]
# Theta(x) = [23.94992273]x + [11.61988981], custo ([12.45536157]),  [572]
# Theta(x) = [23.95080439]x + [11.61894812], custo ([12.45534057]),  [573]
# Theta(x) = [23.95168038]x + [11.61801248], custo ([12.45531983]),  [574]
# Theta(x) = [23.95255073]x + [11.61708285], custo ([12.45529937]),  [575]
# Theta(x) = [23.95341549]x + [11.61615921], custo ([12.45527916]),  [576]
# Theta(x) = [23.95427469]x + [11.6152415], custo ([12.45525921]),  [577]
# Theta(x) = [23.95512836]x + [11.6143297], custo ([12.45523952]),  [578]
# Theta(x) = [23.95597655]x + [11.61342376], custo ([12.45522008]),  [579]
# Theta(x) = [23.95681928]x + [11.61252365], custo ([12.45520089]),  [580]
# Theta(x) = [23.95765658]x + [11.61162932], custo ([12.45518195]),  [581]
# Theta(x) = [23.95848851]x + [11.61074074], custo ([12.45516325]),  [582]
# Theta(x) = [23.95931508]x + [11.60985788], custo ([12.45514479]),  [583]
# Theta(x) = [23.96013634]x + [11.6089807], custo ([12.45512656]),  [584]
# Theta(x) = [23.96095232]x + [11.60810916], custo ([12.45510857]),  [585]
# Theta(x) = [23.96176305]x + [11.60724322], custo ([12.45509081]),  [586]
# Theta(x) = [23.96256857]x + [11.60638285], custo ([12.45507328]),  [587]
# Theta(x) = [23.96336891]x + [11.60552801], custo ([12.45505597]),  [588]
# Theta(x) = [23.9641641]x + [11.60467867], custo ([12.45503888]),  [589]
# Theta(x) = [23.96495418]x + [11.60383479], custo ([12.45502202]),  [590]
# Theta(x) = [23.96573917]x + [11.60299634], custo ([12.45500537]),  [591]
# Theta(x) = [23.96651912]x + [11.60216328], custo ([12.45498893]),  [592]
# Theta(x) = [23.96729406]x + [11.60133558], custo ([12.4549727]),  [593]
# Theta(x) = [23.96806401]x + [11.6005132], custo ([12.45495668]),  [594]
# Theta(x) = [23.968829]x + [11.59969611], custo ([12.45494087]),  [595]
# Theta(x) = [23.96958908]x + [11.59888427], custo ([12.45492526]),  [596]
# Theta(x) = [23.97034427]x + [11.59807766], custo ([12.45490985]),  [597]
# Theta(x) = [23.97109461]x + [11.59727623], custo ([12.45489464]),  [598]
# Theta(x) = [23.97184012]x + [11.59647995], custo ([12.45487962]),  [599]
# Theta(x) = [23.97258083]x + [11.5956888], custo ([12.45486479]),  [600]
# Theta(x) = [23.97331679]x + [11.59490273], custo ([12.45485016]),  [601]
# Theta(x) = [23.97404801]x + [11.59412172], custo ([12.45483571]),  [602]
# Theta(x) = [23.97477452]x + [11.59334573], custo ([12.45482145]),  [603]
# Theta(x) = [23.97549637]x + [11.59257473], custo ([12.45480737]),  [604]
# Theta(x) = [23.97621357]x + [11.59180869], custo ([12.45479347]),  [605]
# Theta(x) = [23.97692616]x + [11.59104757], custo ([12.45477975]),  [606]
# Theta(x) = [23.97763417]x + [11.59029135], custo ([12.45476621]),  [607]
# Theta(x) = [23.97833763]x + [11.58954], custo ([12.45475283]),  [608]
# Theta(x) = [23.97903656]x + [11.58879347], custo ([12.45473963]),  [609]
# Theta(x) = [23.979731]x + [11.58805174], custo ([12.4547266]),  [610]
# Theta(x) = [23.98042097]x + [11.58731479], custo ([12.45471374]),  [611]
# Theta(x) = [23.98110651]x + [11.58658257], custo ([12.45470104]),  [612]
# Theta(x) = [23.98178763]x + [11.58585506], custo ([12.45468851]),  [613]
# Theta(x) = [23.98246438]x + [11.58513223], custo ([12.45467613]),  [614]
# Theta(x) = [23.98313677]x + [11.58441405], custo ([12.45466391]),  [615]
# Theta(x) = [23.98380484]x + [11.58370049], custo ([12.45465185]),  [616]
# Theta(x) = [23.98446862]x + [11.58299152], custo ([12.45463995]),  [617]
# Theta(x) = [23.98512812]x + [11.5822871], custo ([12.4546282]),  [618]
# Theta(x) = [23.98578339]x + [11.58158722], custo ([12.4546166]),  [619]
# Theta(x) = [23.98643444]x + [11.58089183], custo ([12.45460514]),  [620]
# Theta(x) = [23.9870813]x + [11.58020092], custo ([12.45459384]),  [621]
# Theta(x) = [23.98772401]x + [11.57951445], custo ([12.45458267]),  [622]
# Theta(x) = [23.98836258]x + [11.57883239], custo ([12.45457166]),  [623]
# Theta(x) = [23.98899705]x + [11.57815472], custo ([12.45456078]),  [624]
# Theta(x) = [23.98962743]x + [11.57748141], custo ([12.45455004]),  [625]
# Theta(x) = [23.99025376]x + [11.57681243], custo ([12.45453944]),  [626]
# Theta(x) = [23.99087607]x + [11.57614775], custo ([12.45452898]),  [627]
# Theta(x) = [23.99149437]x + [11.57548735], custo ([12.45451865]),  [628]
# Theta(x) = [23.99210869]x + [11.57483119], custo ([12.45450845]),  [629]
# Theta(x) = [23.99271907]x + [11.57417925], custo ([12.45449838]),  [630]
# Theta(x) = [23.99332552]x + [11.5735315], custo ([12.45448845]),  [631]
# Theta(x) = [23.99392807]x + [11.57288792], custo ([12.45447863]),  [632]
# Theta(x) = [23.99452675]x + [11.57224848], custo ([12.45446895]),  [633]
# Theta(x) = [23.99512157]x + [11.57161315], custo ([12.45445939]),  [634]
# Theta(x) = [23.99571257]x + [11.5709819], custo ([12.45444995]),  [635]
# Theta(x) = [23.99629977]x + [11.57035472], custo ([12.45444064]),  [636]
# Theta(x) = [23.99688319]x + [11.56973157], custo ([12.45443144]),  [637]
# Theta(x) = [23.99746287]x + [11.56911242], custo ([12.45442236]),  [638]
# Theta(x) = [23.99803881]x + [11.56849726], custo ([12.4544134]),  [639]
# Theta(x) = [23.99861105]x + [11.56788605], custo ([12.45440455]),  [640]
# Theta(x) = [23.99917961]x + [11.56727877], custo ([12.45439581]),  [641]
# Theta(x) = [23.99974452]x + [11.5666754], custo ([12.45438719]),  [642]
# Theta(x) = [24.00030579]x + [11.56607591], custo ([12.45437868]),  [643]
# Theta(x) = [24.00086345]x + [11.56548027], custo ([12.45437027]),  [644]
# Theta(x) = [24.00141753]x + [11.56488847], custo ([12.45436198]),  [645]
# Theta(x) = [24.00196804]x + [11.56430047], custo ([12.45435379]),  [646]
# Theta(x) = [24.00251501]x + [11.56371625], custo ([12.45434571]),  [647]
# Theta(x) = [24.00305847]x + [11.56313579], custo ([12.45433773]),  [648]
# Theta(x) = [24.00359843]x + [11.56255906], custo ([12.45432985]),  [649]
# Theta(x) = [24.00413492]x + [11.56198603], custo ([12.45432207]),  [650]
# Theta(x) = [24.00466796]x + [11.5614167], custo ([12.45431439]),  [651]
# Theta(x) = [24.00519757]x + [11.56085102], custo ([12.45430681]),  [652]
# Theta(x) = [24.00572377]x + [11.56028899], custo ([12.45429933]),  [653]
# Theta(x) = [24.0062466]x + [11.55973056], custo ([12.45429195]),  [654]
# Theta(x) = [24.00676605]x + [11.55917573], custo ([12.45428465]),  [655]
# Theta(x) = [24.00728217]x + [11.55862447], custo ([12.45427746]),  [656]
# Theta(x) = [24.00779497]x + [11.55807675], custo ([12.45427035]),  [657]
# Theta(x) = [24.00830448]x + [11.55753255], custo ([12.45426334]),  [658]
# Theta(x) = [24.0088107]x + [11.55699186], custo ([12.45425641]),  [659]
# Theta(x) = [24.00931367]x + [11.55645464], custo ([12.45424958]),  [660]
# ...
# Theta(x) = [24.05142389]x + [11.51147691], custo ([12.45383368]),  [781]
# Theta(x) = [24.05165283]x + [11.51123239], custo ([12.45383226]),  [782]
# Theta(x) = [24.0518803]x + [11.51098943], custo ([12.45383086]),  [783]
# Theta(x) = [24.0521063]x + [11.51074804], custo ([12.45382948]),  [784]
# Theta(x) = [24.05233085]x + [11.51050819], custo ([12.45382812]),  [785]
# Theta(x) = [24.05255396]x + [11.51026989], custo ([12.45382678]),  [786]
# Theta(x) = [24.05277563]x + [11.51003313], custo ([12.45382545]),  [787]
# Theta(x) = [24.05299588]x + [11.50979788], custo ([12.45382414]),  [788]
# Theta(x) = [24.05321471]x + [11.50956415], custo ([12.45382284]),  [789]
# Theta(x) = [24.05343213]x + [11.50933192], custo ([12.45382157]),  [790]
# Theta(x) = [24.05364816]x + [11.50910119], custo ([12.45382031]),  [791]
# Theta(x) = [24.05386279]x + [11.50887194], custo ([12.45381906]),  [792]
# Theta(x) = [24.05407605]x + [11.50864416], custo ([12.45381783]),  [793]
# Theta(x) = [24.05428793]x + [11.50841785], custo ([12.45381662]),  [794]
# Theta(x) = [24.05449845]x + [11.50819299], custo ([12.45381542]),  [795]
# Theta(x) = [24.05470762]x + [11.50796958], custo ([12.45381424]),  [796]
# Theta(x) = [24.05491544]x + [11.5077476], custo ([12.45381307]),  [797]
# Theta(x) = [24.05512193]x + [11.50752706], custo ([12.45381192]),  [798]
# Theta(x) = [24.05532709]x + [11.50730793], custo ([12.45381078]),  [799]
# Theta(x) = [24.05553093]x + [11.50709021], custo ([12.45380966]),  [800]
# Theta(x) = [24.05573346]x + [11.50687389], custo ([12.45380855]),  [801]
# Theta(x) = [24.05593468]x + [11.50665896], custo ([12.45380746]),  [802]
# Theta(x) = [24.05613462]x + [11.50644541], custo ([12.45380638]),  [803]
# Theta(x) = [24.05633326]x + [11.50623324], custo ([12.45380531]),  [804]
# Theta(x) = [24.05653063]x + [11.50602243], custo ([12.45380426]),  [805]
# Theta(x) = [24.05672673]x + [11.50581298], custo ([12.45380322]),  [806]
# Theta(x) = [24.05692157]x + [11.50560487], custo ([12.45380219]),  [807]
# Theta(x) = [24.05711515]x + [11.5053981], custo ([12.45380118]),  [808]
# Theta(x) = [24.0573075]x + [11.50519267], custo ([12.45380018]),  [809]
# Theta(x) = [24.0574986]x + [11.50498855], custo ([12.4537992]),  [810]
# Theta(x) = [24.05768847]x + [11.50478574], custo ([12.45379822]),  [811]
# Theta(x) = [24.05787713]x + [11.50458424], custo ([12.45379726]),  [812]
# Theta(x) = [24.05806457]x + [11.50438404], custo ([12.45379631]),  [813]
# Theta(x) = [24.0582508]x + [11.50418512], custo ([12.45379537]),  [814]
# Theta(x) = [24.05843584]x + [11.50398748], custo ([12.45379445]),  [815]
# Theta(x) = [24.05861969]x + [11.50379112], custo ([12.45379353]),  [816]
# Theta(x) = [24.05880236]x + [11.50359601], custo ([12.45379263]),  [817]
# Theta(x) = [24.05898385]x + [11.50340216], custo ([12.45379174]),  [818]
# Theta(x) = [24.05916417]x + [11.50320956], custo ([12.45379086]),  [819]
# Theta(x) = [24.05934333]x + [11.5030182], custo ([12.45379]),  [820]
# Theta(x) = [24.05952135]x + [11.50282806], custo ([12.45378914]),  [821]
# Theta(x) = [24.05969821]x + [11.50263915], custo ([12.4537883]),  [822]
# Theta(x) = [24.05987394]x + [11.50245145], custo ([12.45378746]),  [823]
# Theta(x) = [24.06004854]x + [11.50226496], custo ([12.45378664]),  [824]
# Theta(x) = [24.06022202]x + [11.50207967], custo ([12.45378582]),  [825]
# Theta(x) = [24.06039438]x + [11.50189558], custo ([12.45378502]),  [826]
# Theta(x) = [24.06056564]x + [11.50171266], custo ([12.45378423]),  [827]
# Theta(x) = [24.06073579]x + [11.50153092], custo ([12.45378345]),  [828]
# Theta(x) = [24.06090485]x + [11.50135035], custo ([12.45378267]),  [829]
# Theta(x) = [24.06107282]x + [11.50117094], custo ([12.45378191]),  [830]
# Theta(x) = [24.06123971]x + [11.50099269], custo ([12.45378116]),  [831]
# Theta(x) = [24.06140552]x + [11.50081558], custo ([12.45378042]),  [832]
# Theta(x) = [24.06157027]x + [11.50063961], custo ([12.45377968]),  [833]
# Theta(x) = [24.06173397]x + [11.50046477], custo ([12.45377896]),  [834]
# Theta(x) = [24.0618966]x + [11.50029106], custo ([12.45377824]),  [835]
# Theta(x) = [24.0620582]x + [11.50011846], custo ([12.45377754]),  [836]
# Theta(x) = [24.06221875]x + [11.49994698], custo ([12.45377684]),  [837]
# Theta(x) = [24.06237827]x + [11.49977659], custo ([12.45377615]),  [838]
# Theta(x) = [24.06253677]x + [11.4996073], custo ([12.45377548]),  [839]
# Theta(x) = [24.06269424]x + [11.4994391], custo ([12.45377481]),  [840]
# Theta(x) = [24.06285071]x + [11.49927199], custo ([12.45377414]),  [841]
# Theta(x) = [24.06300616]x + [11.49910594], custo ([12.45377349]),  [842]
# Theta(x) = [24.06316062]x + [11.49894097], custo ([12.45377285]),  [843]
# Theta(x) = [24.06331409]x + [11.49877705], custo ([12.45377221]),  [844]
# Theta(x) = [24.06346656]x + [11.49861419], custo ([12.45377158]),  [845]
# Theta(x) = [24.06361806]x + [11.49845238], custo ([12.45377096]),  [846]
# Theta(x) = [24.06376858]x + [11.49829161], custo ([12.45377035]),  [847]
# Theta(x) = [24.06391814]x + [11.49813187], custo ([12.45376975]),  [848]
# Theta(x) = [24.06406673]x + [11.49797316], custo ([12.45376915]),  [849]
# Theta(x) = [24.06421437]x + [11.49781547], custo ([12.45376856]),  [850]
# Theta(x) = [24.06436106]x + [11.49765879], custo ([12.45376798]),  [851]
# Theta(x) = [24.0645068]x + [11.49750312], custo ([12.4537674]),  [852]
# Theta(x) = [24.06465161]x + [11.49734845], custo ([12.45376684]),  [853]
# Theta(x) = [24.06479549]x + [11.49719478], custo ([12.45376628]),  [854]
# Theta(x) = [24.06493844]x + [11.49704209], custo ([12.45376573]),  [855]
# Theta(x) = [24.06508047]x + [11.49689039], custo ([12.45376518]),  [856]
# Theta(x) = [24.06522159]x + [11.49673966], custo ([12.45376464]),  [857]
# Theta(x) = [24.0653618]x + [11.4965899], custo ([12.45376411]),  [858]
# Theta(x) = [24.06550111]x + [11.49644111], custo ([12.45376359]),  [859]
# Theta(x) = [24.06563952]x + [11.49629327], custo ([12.45376307]),  [860]
# Theta(x) = [24.06577705]x + [11.49614638], custo ([12.45376256]),  [861]
# Theta(x) = [24.06591368]x + [11.49600044], custo ([12.45376205]),  [862]
# Theta(x) = [24.06604945]x + [11.49585543], custo ([12.45376156]),  [863]
# Theta(x) = [24.06618433]x + [11.49571136], custo ([12.45376106]),  [864]
# Theta(x) = [24.06631835]x + [11.49556821], custo ([12.45376058]),  [865]
# Theta(x) = [24.06645151]x + [11.49542599], custo ([12.4537601]),  [866]
# Theta(x) = [24.06658381]x + [11.49528468], custo ([12.45375963]),  [867]
# Theta(x) = [24.06671526]x + [11.49514427], custo ([12.45375916]),  [868]
# Theta(x) = [24.06684587]x + [11.49500477], custo ([12.4537587]),  [869]
# Theta(x) = [24.06697564]x + [11.49486617], custo ([12.45375824]),  [870]
# Theta(x) = [24.06710457]x + [11.49472846], custo ([12.4537578]),  [871]
# Theta(x) = [24.06723267]x + [11.49459164], custo ([12.45375735]),  [872]
# Theta(x) = [24.06735995]x + [11.49445569], custo ([12.45375691]),  [873]
# Theta(x) = [24.06748641]x + [11.49432062], custo ([12.45375648]),  [874]
# Theta(x) = [24.06761205]x + [11.49418642], custo ([12.45375606]),  [875]
# Theta(x) = [24.06773689]x + [11.49405308], custo ([12.45375563]),  [876]
# Theta(x) = [24.06786093]x + [11.49392059], custo ([12.45375522]),  [877]
# Theta(x) = [24.06798417]x + [11.49378896], custo ([12.45375481]),  [878]
# Theta(x) = [24.06810661]x + [11.49365818], custo ([12.4537544]),  [879]
# Theta(x) = [24.06822827]x + [11.49352824], custo ([12.453754]),  [880]
# Theta(x) = [24.06834915]x + [11.49339913], custo ([12.45375361]),  [881]
# Theta(x) = [24.06846925]x + [11.49327085], custo ([12.45375322]),  [882]
# Theta(x) = [24.06858857]x + [11.4931434], custo ([12.45375283]),  [883]
# Theta(x) = [24.06870713]x + [11.49301677], custo ([12.45375245]),  [884]
# Theta(x) = [24.06882493]x + [11.49289095], custo ([12.45375208]),  [885]
# Theta(x) = [24.06894197]x + [11.49276594], custo ([12.45375171]),  [886]
# Theta(x) = [24.06905825]x + [11.49264174], custo ([12.45375134]),  [887]
# Theta(x) = [24.06917379]x + [11.49251833], custo ([12.45375098]),  [888]
# Theta(x) = [24.06928859]x + [11.49239572], custo ([12.45375063]),  [889]
# Theta(x) = [24.06940265]x + [11.49227389], custo ([12.45375028]),  [890]
# Theta(x) = [24.06951597]x + [11.49215285], custo ([12.45374993]),  [891]
# Theta(x) = [24.06962857]x + [11.49203259], custo ([12.45374959]),  [892]
# Theta(x) = [24.06974044]x + [11.4919131], custo ([12.45374925]),  [893]
# Theta(x) = [24.06985159]x + [11.49179438], custo ([12.45374891]),  [894]
# Theta(x) = [24.06996203]x + [11.49167642], custo ([12.45374858]),  [895]
# Theta(x) = [24.07007175]x + [11.49155922], custo ([12.45374826]),  [896]
# Theta(x) = [24.07018077]x + [11.49144278], custo ([12.45374794]),  [897]
# Theta(x) = [24.07028909]x + [11.49132708], custo ([12.45374762]),  [898]
# Theta(x) = [24.07039672]x + [11.49121213], custo ([12.45374731]),  [899]
# Theta(x) = [24.07050365]x + [11.49109792], custo ([12.453747]),  [900]
# Theta(x) = [24.07060989]x + [11.49098444], custo ([12.45374669]),  [901]
# Theta(x) = [24.07071545]x + [11.49087169], custo ([12.45374639]),  [902]
# Theta(x) = [24.07082034]x + [11.49075966], custo ([12.4537461]),  [903]
# Theta(x) = [24.07092454]x + [11.49064836], custo ([12.4537458]),  [904]
# Theta(x) = [24.07102808]x + [11.49053777], custo ([12.45374551]),  [905]
# Theta(x) = [24.07113095]x + [11.4904279], custo ([12.45374523]),  [906]
# Theta(x) = [24.07123316]x + [11.49031873], custo ([12.45374494]),  [907]
# Theta(x) = [24.07133472]x + [11.49021026], custo ([12.45374467]),  [908]
# Theta(x) = [24.07143561]x + [11.49010249], custo ([12.45374439]),  [909]
# Theta(x) = [24.07153587]x + [11.48999541], custo ([12.45374412]),  [910]
# Theta(x) = [24.07163547]x + [11.48988902], custo ([12.45374385]),  [911]
# Theta(x) = [24.07173444]x + [11.48978332], custo ([12.45374359]),  [912]
# Theta(x) = [24.07183277]x + [11.48967829], custo ([12.45374332]),  [913]
# Theta(x) = [24.07193046]x + [11.48957394], custo ([12.45374307]),  [914]
# Theta(x) = [24.07202753]x + [11.48947027], custo ([12.45374281]),  [915]
# Theta(x) = [24.07212398]x + [11.48936725], custo ([12.45374256]),  [916]
# Theta(x) = [24.0722198]x + [11.4892649], custo ([12.45374231]),  [917]
# Theta(x) = [24.07231501]x + [11.48916321], custo ([12.45374207]),  [918]
# Theta(x) = [24.0724096]x + [11.48906218], custo ([12.45374183]),  [919]
# Theta(x) = [24.07250359]x + [11.48896179], custo ([12.45374159]),  [920]
# Theta(x) = [24.07259697]x + [11.48886205], custo ([12.45374135]),  [921]
# Theta(x) = [24.07268976]x + [11.48876295], custo ([12.45374112]),  [922]
# Theta(x) = [24.07278194]x + [11.48866448], custo ([12.45374089]),  [923]
# Theta(x) = [24.07287354]x + [11.48856665], custo ([12.45374066]),  [924]
# Theta(x) = [24.07296454]x + [11.48846945], custo ([12.45374044]),  [925]
# Theta(x) = [24.07305496]x + [11.48837288], custo ([12.45374022]),  [926]
# Theta(x) = [24.0731448]x + [11.48827692], custo ([12.45374]),  [927]
# Theta(x) = [24.07323405]x + [11.48818158], custo ([12.45373978]),  [928]
# Theta(x) = [24.07332274]x + [11.48808686], custo ([12.45373957]),  [929]
# Theta(x) = [24.07341086]x + [11.48799274], custo ([12.45373936]),  [930]
# Theta(x) = [24.0734984]x + [11.48789923], custo ([12.45373916]),  [931]
# Theta(x) = [24.07358539]x + [11.48780632], custo ([12.45373895]),  [932]
# Theta(x) = [24.07367182]x + [11.48771401], custo ([12.45373875]),  [933]
# Theta(x) = [24.07375769]x + [11.4876223], custo ([12.45373855]),  [934]
# Theta(x) = [24.07384301]x + [11.48753117], custo ([12.45373835]),  [935]
# Theta(x) = [24.07392777]x + [11.48744062], custo ([12.45373816]),  [936]
# Theta(x) = [24.074012]x + [11.48735067], custo ([12.45373797]),  [937]
# Theta(x) = [24.07409568]x + [11.48726128], custo ([12.45373778]),  [938]
# Theta(x) = [24.07417883]x + [11.48717248], custo ([12.45373759]),  [939]
# Theta(x) = [24.07426144]x + [11.48708424], custo ([12.45373741]),  [940]
# Theta(x) = [24.07434352]x + [11.48699657], custo ([12.45373722]),  [941]
# Theta(x) = [24.07442507]x + [11.48690947], custo ([12.45373705]),  [942]
# Theta(x) = [24.07450609]x + [11.48682293], custo ([12.45373687]),  [943]
# Theta(x) = [24.0745866]x + [11.48673694], custo ([12.45373669]),  [944]
# Theta(x) = [24.07466659]x + [11.4866515], custo ([12.45373652]),  [945]
# Theta(x) = [24.07474606]x + [11.48656662], custo ([12.45373635]),  [946]
# Theta(x) = [24.07482502]x + [11.48648228], custo ([12.45373618]),  [947]
# Theta(x) = [24.07490348]x + [11.48639848], custo ([12.45373601]),  [948]
# Theta(x) = [24.07498143]x + [11.48631522], custo ([12.45373585]),  [949]
# Theta(x) = [24.07505888]x + [11.4862325], custo ([12.45373569]),  [950]
# Theta(x) = [24.07513583]x + [11.48615031], custo ([12.45373553]),  [951]
# Theta(x) = [24.07521228]x + [11.48606865], custo ([12.45373537]),  [952]
# Theta(x) = [24.07528825]x + [11.48598751], custo ([12.45373521]),  [953]
# Theta(x) = [24.07536372]x + [11.4859069], custo ([12.45373506]),  [954]
# Theta(x) = [24.07543871]x + [11.4858268], custo ([12.45373491]),  [955]
# Theta(x) = [24.07551322]x + [11.48574722], custo ([12.45373476]),  [956]
# Theta(x) = [24.07558725]x + [11.48566815], custo ([12.45373461]),  [957]
# Theta(x) = [24.0756608]x + [11.48558958], custo ([12.45373446]),  [958]
# Theta(x) = [24.07573388]x + [11.48551153], custo ([12.45373432]),  [959]
# Theta(x) = [24.07580649]x + [11.48543397], custo ([12.45373418]),  [960]
# Theta(x) = [24.07587864]x + [11.48535692], custo ([12.45373404]),  [961]
# Theta(x) = [24.07595032]x + [11.48528036], custo ([12.4537339]),  [962]
# Theta(x) = [24.07602153]x + [11.48520429], custo ([12.45373376]),  [963]
# Theta(x) = [24.07609229]x + [11.48512871], custo ([12.45373363]),  [964]
# Theta(x) = [24.0761626]x + [11.48505362], custo ([12.45373349]),  [965]
# Theta(x) = [24.07623245]x + [11.48497901], custo ([12.45373336]),  [966]
# Theta(x) = [24.07630186]x + [11.48490488], custo ([12.45373323]),  [967]
# Theta(x) = [24.07637081]x + [11.48483123], custo ([12.4537331]),  [968]
# Theta(x) = [24.07643933]x + [11.48475805], custo ([12.45373297]),  [969]
# Theta(x) = [24.0765074]x + [11.48468534], custo ([12.45373285]),  [970]
# Theta(x) = [24.07657504]x + [11.4846131], custo ([12.45373273]),  [971]
# Theta(x) = [24.07664224]x + [11.48454132], custo ([12.4537326]),  [972]
# Theta(x) = [24.07670901]x + [11.48447], custo ([12.45373248]),  [973]
# Theta(x) = [24.07677535]x + [11.48439915], custo ([12.45373236]),  [974]
# Theta(x) = [24.07684126]x + [11.48432875], custo ([12.45373225]),  [975]
# Theta(x) = [24.07690675]x + [11.4842588], custo ([12.45373213]),  [976]
# Theta(x) = [24.07697182]x + [11.4841893], custo ([12.45373202]),  [977]
# Theta(x) = [24.07703647]x + [11.48412025], custo ([12.4537319]),  [978]
# Theta(x) = [24.0771007]x + [11.48405164], custo ([12.45373179]),  [979]
# Theta(x) = [24.07716452]x + [11.48398347], custo ([12.45373168]),  [980]
# Theta(x) = [24.07722793]x + [11.48391574], custo ([12.45373157]),  [981]
# Theta(x) = [24.07729093]x + [11.48384845], custo ([12.45373147]),  [982]
# Theta(x) = [24.07735353]x + [11.48378159], custo ([12.45373136]),  [983]
# Theta(x) = [24.07741572]x + [11.48371516], custo ([12.45373126]),  [984]
# Theta(x) = [24.07747752]x + [11.48364916], custo ([12.45373115]),  [985]
# Theta(x) = [24.07753892]x + [11.48358358], custo ([12.45373105]),  [986]
# Theta(x) = [24.07759992]x + [11.48351843], custo ([12.45373095]),  [987]
# Theta(x) = [24.07766053]x + [11.48345369], custo ([12.45373085]),  [988]
# Theta(x) = [24.07772075]x + [11.48338937], custo ([12.45373075]),  [989]
# Theta(x) = [24.07778058]x + [11.48332546], custo ([12.45373066]),  [990]
# Theta(x) = [24.07784003]x + [11.48326196], custo ([12.45373056]),  [991]
# Theta(x) = [24.0778991]x + [11.48319887], custo ([12.45373047]),  [992]
# Theta(x) = [24.07795778]x + [11.48313619], custo ([12.45373037]),  [993]
# Theta(x) = [24.07801609]x + [11.48307391], custo ([12.45373028]),  [994]
# Theta(x) = [24.07807403]x + [11.48301203], custo ([12.45373019]),  [995]
# Theta(x) = [24.07813159]x + [11.48295055], custo ([12.4537301]),  [996]
# Theta(x) = [24.07818878]x + [11.48288947], custo ([12.45373001]),  [997]
# Theta(x) = [24.0782456]x + [11.48282877], custo ([12.45372993]),  [998]
# Theta(x) = [24.07830206]x + [11.48276847], custo ([12.45372984]),  [999]
# Theta(x) = 24.078302060699745x + 11.482768471454992

# %% [markdown]
# ### GRADIENTE DESCENDENTE ESTOCASTICO

# %%
def gradiente_descendente_estocastico(x, y, Custo = None):
    wo = w = 0
    inter = 1000
    alpha = 0.008  #learning rate
    n = len(x)
    custo = custot = np.array([])
    for t in range(inter):
        y_pred = x*w + wo
        custot = ((1/n) * sum([val**2 for val in (y-y_pred)]))
        custo = np.append(custo, custot) 
        wo = wo + alpha*(y- y_pred)
        w = w + alpha*(y - y_pred)*x
  
    plt.scatter(x, y, marker = "x", color = "black")
    plt.scatter(x,y_pred, color = "red")
    plt.xlabel("Independent variable")
    plt.ylabel("Dependent Variable")
    plt.show()
    print(f"Theta(x) = {w[-1]}x + {wo[-1]}")

    if Custo:
      plt.plot(np.array([t for t in range(0, inter)]), custo, color = "orange")
      plt.xlabel("Iteration")
      plt.ylabel("Cost function")
      plt.show()

gradiente_descendente_estocastico(x1,y1, Custo =True)
# Out:
# Theta(x) = [21.84129937]x + [14.82776603]

# %% [markdown]
# #### REGRESSÃO LINEAR ANALÍTICA

# %%
x = np.array([[1 ,2 ,3, 4]])
y = np.array([[2, 4, 6, 8]])

df = pd.DataFrame({'Peso': np.array([18.141,42.404,16.1,13.005,23.583,7.710,17.46,3.855,14.966,4.308,9.524,35.828]),
                    'Altura': np.array([1.087,1.613,0.953,1.003,1.156,0.978,1.092,0.572,0.940,0.597,0.838,1.473]),
                    'Cateter': np.array([37, 50, 34, 36, 43, 28, 37, 20, 34, 30, 38, 47])})
var_1 = df["Peso"] 
var_2 = df["Altura"]
var_prev = df["Cateter"]

# %%
X = np.ones(24).reshape(12,2)
X[:,1] = df["Altura"]
X = np.matrix(X)
y = np.matrix(df["Cateter"]).reshape((12,1))
w = np.linalg.inv((X.T*X))*X.T*y
print(f"Theta(x) = {w[1]}x + {w[0]}")
plt.plot(np.array(X[:,1]), np.array(X*w), color = "red")
plt.show()
# Out:
# Theta(x) = [[24.08702511]]x + [[11.47345142]]

# %% [markdown]
# #### REGRESSÃO LINEAR ANALÍTICA - MULTIPLA

# %%
def Analitical_Mult_Linreg(x1, x2, var_prev):
    
    X = np.ones(len(x1)*3).reshape(len(x1),3)
    X[:,1] = x1
    X[:,2] = x2
    X = np.matrix(X)
    y = np.matrix(var_prev).reshape((12,1))
    w = np.linalg.inv((X.T*X))*X.T*y
    y_pred = X*w
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x1, x2, y, color = "red")    
    ax.scatter(x1, x2, y_pred, color = "black")
    return f"Theta(x1, x2) = {w[2]}x1 + {w[1]}x2 + {w[0]}"

Analitical_Mult_Linreg(var_1, var_2 , var_prev)
# Out:
# 'Theta(x1, x2) = [[8.80257597]]x1 + [[0.40766255]]x2 + [[20.11432093]]'

# %% [markdown]
# Regressão Linear Múltipla
# ypred = wo + w1*xi1 + w2xi2
#
# Regra de atualização:
# w(t) = w(t-1) + alpha*(1/n)*sum(ei*(t-1)xi)
